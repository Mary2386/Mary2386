# %%
# !pip install numpy pandas matplotlib seaborn
# Out:
# Requirement already satisfied: numpy in c:\users\maryb\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\maryb\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\maryb\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: seaborn in c:\users\maryb\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\maryb\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\maryb\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\maryb\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\maryb\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\maryb\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\maryb\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\maryb\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\maryb\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\maryb\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\maryb\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\maryb\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Replace 'path/to/your/titanic.csv' with the actual file path
df = pd.read_csv(r'C:\Users\MaryB\Downloads\kaggle Datasets\archive\data.csv')

# %%
print(df.head())
# Out:
#           id             title          type                  genres  \
# 0  tt0903747      Breaking Bad      tvSeries  Crime, Drama, Thriller
# 1  tt5491994   Planet Earth II  tvMiniSeries             Documentary
# 2  tt0185906  Band of Brothers  tvMiniSeries     Drama, History, War
# 3  tt0795176      Planet Earth  tvMiniSeries     Documentary, Family
# 4  tt5152226      Tree of Life      tvSeries                   Drama
#
#    averageRating  numVotes  releaseYear
# 0            9.5   2220756         2008
# 1            9.5    161283         2016
# 2            9.4    542837         2001
# 3            9.4    222817         2006
# 4            9.4     11445         2014

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6035 entries, 0 to 6034
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             6035 non-null   object
#  1   title          6035 non-null   object
#  2   type           6035 non-null   object
#  3   genres         6035 non-null   object
#  4   averageRating  6035 non-null   float64
#  5   numVotes       6035 non-null   int64
#  6   releaseYear    6035 non-null   int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 330.2+ KB
# id               0
# title            0
# type             0
# genres           0
# averageRating    0
# numVotes         0
# releaseYear      0
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['releaseYear'], bins=30, kde=True)
plt.title('Age Distribution of Titanic Passengers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
